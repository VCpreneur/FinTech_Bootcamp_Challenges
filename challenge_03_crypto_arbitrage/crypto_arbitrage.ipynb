# %% [markdown]
# ## Crypto Arbitrage
#
# In this Challenge, you'll take on the role of an analyst at a high-tech investment firm. The vice president (VP) of your department is considering arbitrage opportunities in Bitcoin and other cryptocurrencies. As Bitcoin trades on markets across the globe, can you capitalize on simultaneous price dislocations in those markets by using the powers of Pandas?
#
# For this assignment, you’ll sort through historical trade data for Bitcoin on two exchanges: Bitstamp and Coinbase. Your task is to apply the three phases of financial analysis to determine if any arbitrage opportunities exist for Bitcoin.
#
# This aspect of the Challenge will consist of 3 phases.
#
# 1. Collect the data.
#
# 2. Prepare the data.
#
# 3. Analyze the data.

# %% [markdown]
# ###  Import the required libraries and dependencies.

# %%
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ## Collect the Data
#
# To collect the data that you’ll need, complete the following steps:
#
# Instructions.
#
# 1. Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.
#
# 2. Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.
#
# 3. Repeat Steps 1 and 2 for `coinbase.csv` file.

# %% [markdown]
# ### Step 1: Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.

# %%
# Read in the CSV file called "bitstamp.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Date"
# Set the parse_dates and infer_datetime_format parameters
bitstamp = pd.read_csv(
    Path('./Resources/bitstamp.csv'), 
    index_col="Timestamp", 
    parse_dates=True, 
    infer_datetime_format=True
)

# %% [markdown]
# ### Step 2: Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
bitstamp.head()
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329

# %%
bitstamp.tail()
# Out:
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6935.01  6939.07  6922.56  $6922.56    1.044354
# 2018-03-31 23:56:00  6922.02  6922.02  6918.00  $6920.32    3.069539
# 2018-03-31 23:57:00  6920.33  6936.42  6920.33  $6934.72   28.239049
# 2018-03-31 23:58:00  6927.65  6929.42  6927.65  $6927.65    0.839507
# 2018-03-31 23:59:00  6929.98  6929.98  6928.00  $6928.01    0.209363
#
#                         USD Volume  Weighted Price
# Timestamp
# 2018-03-31 23:55:00    7240.034602     6932.550078
# 2018-03-31 23:56:00   21245.076275     6921.260233
# 2018-03-31 23:57:00  195789.408220     6933.286106
# 2018-03-31 23:58:00    5817.007705     6929.080007
# 2018-03-31 23:59:00    1450.735763     6929.289993

# %%
# Generate summary statistics for the `bitstamp` DataFrame

bitstamp.describe()
# Out:
#                 Open           High            Low     BTC Volume  \
# count  129067.000000  129067.000000  129067.000000  129067.000000
# mean    10459.993683   10472.970114   10446.214703      11.792878
# std      2315.909269    2318.929342    2312.331601      21.799938
# min      5945.950000    5975.060000    5920.720000       0.000039
# 25%      8613.985000    8621.655000    8604.440000       1.711874
# 50%     10145.300000   10156.410000   10131.740000       4.994095
# 75%     11444.455000   11453.990000   11431.970000      12.717950
# max     17234.980000   17234.990000   17214.960000     580.646391
#
#          USD Volume  Weighted Price
# count  1.290670e+05   129067.000000
# mean   1.177496e+05    10459.384448
# std    2.070551e+05     2315.723480
# min    3.333436e-01     5949.997212
# 25%    1.773244e+04     8613.587020
# 50%    5.188050e+04    10144.740411
# 75%    1.313104e+05    11443.791560
# max    5.483271e+06    17227.810502

# %%
# The count function in describe() counts non-NaN values in every row
# While the len(df.index) counts all rows regardless of NaN values 

len(bitstamp.index)
# Out:
# 129540

# %%
# Check the data type of each column in the DataFrame

bitstamp.dtypes
# Out:
# Open              float64
# High              float64
# Low               float64
# Close              object
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %% [markdown]
# ### Step 3: Repeat Steps 1 and 2 for `coinbase.csv` file.

# %%
# Read in the CSV file called "coinbase.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Timestamp"
# Set the parse_dates and infer_datetime_format parameters
coinbase = pd.read_csv(
    Path('./Resources/coinbase.csv'), 
    index_col="Timestamp", 
    parse_dates=True, 
    infer_datetime_format=True
)

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
coinbase.head()
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401

# %%
coinbase.tail()
# Out:
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6945.20  6948.06  6930.00   $6930.0    5.802288
# 2018-03-31 23:56:00  6930.00  6930.01  6930.00  $6930.01    0.625053
# 2018-03-31 23:57:00  6930.01  6933.91  6930.01  $6933.91    0.776431
# 2018-03-31 23:58:00  6933.91  6938.00  6933.90  $6937.31    0.133413
# 2018-03-31 23:59:00  6937.30  6937.30  6931.09   $6934.0    1.012720
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-03-31 23:55:00  40243.918480     6935.869979
# 2018-03-31 23:56:00   4331.620701     6930.005567
# 2018-03-31 23:57:00   5382.532162     6932.405747
# 2018-03-31 23:58:00    925.356547     6936.048538
# 2018-03-31 23:59:00   7022.275088     6934.070316

# %%
# Generate summary statistics for the `coinbase` DataFrame

coinbase.describe()
# Out:
#                 Open           High            Low     BTC Volume  \
# count  129322.000000  129322.000000  129322.000000  129322.000000
# mean    10449.213185   10456.118514   10441.872248      15.666556
# std      2317.194653    2317.710389    2316.570594      27.481647
# min      5882.300000    5907.280000    5873.000000       0.000442
# 25%      8609.230000    8613.872500    8603.505000       2.999125
# 50%     10137.440000   10145.900000   10127.880000       7.092572
# 75%     11397.522500   11400.000000   11390.000000      16.954279
# max     17178.000000   17178.000000   17177.990000     959.084903
#
#          USD Volume  Weighted Price
# count  1.293220e+05   129322.000000
# mean   1.572565e+05    10448.964130
# std    2.667879e+05     2317.167139
# min    6.699174e+00     5883.394912
# 25%    3.071222e+04     8609.135020
# 50%    7.461366e+04    10136.035004
# 75%    1.754530e+05    11396.970843
# max    1.152334e+07    17177.995495

# %%
# The count function in describe() counts non-NaN values in every row
# While the len(df.index) counts all rows regardless of NaN values

len(coinbase.index)
# Out:
# 129540

# %%
# Check the data type of each column in the DataFrame

coinbase.dtypes
# Out:
# Open              float64
# High              float64
# Low               float64
# Close              object
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %%
# To see if there is a diffrence in the length of both dataframes: 

len(bitstamp.index) - len(coinbase.index)
# Out:
# 0

# %% [markdown]
# ## Prepare the Data
#
# To prepare and clean your data for analysis, complete the following steps:
#
# 1. For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.
#
# 2. Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.
#
# 3. Convert the data type of the Close column to a `float`.
#
# 4. Review the data for duplicated values, and drop them if necessary.
#
# 5. Repeat Steps 1–4 for the coinbase DataFrame.

# %% [markdown]
# ### Step 1: For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.

# %%
# For the bitstamp DataFrame, replace or drop all NaNs or missing values in the DataFrame

# Check how many missing values are there in the DataFrame
bitstamp.isnull().sum()
# Out:
# Open              473
# High              473
# Low               473
# Close               0
# BTC Volume        473
# USD Volume        473
# Weighted Price    473
# dtype: int64

# %%
# Drop all NaNs or missing values in the DataFrame

bitstamp = bitstamp.dropna()

# %% [markdown]
# ### Step 2: Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.

# %%
# Use the str.replace function to remove the dollar sign, $

bitstamp.loc[:, "Close"] = bitstamp.loc[:, "Close"].str.replace("$", "", regex=True)

# Alternative code: bitstamp["Close"] = bitstamp["Close"].str.replace("$", "", regex=True)

# Call the head function to review the first 5 rows of the DataFrame
bitstamp.head()
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329

# %% [markdown]
# ### Step 3: Convert the data type of the Close column to a `float`.

# %%
# Convert the Close data type to a float
bitstamp.loc[:, "Close"] = bitstamp.loc[:, "Close"].astype("float")

# Alternative code: bitstamp["Close"] = bitstamp["Close"].astype("float")

# Review data types after conversion
bitstamp.dtypes
# Out:
# Open              float64
# High              float64
# Low               float64
# Close             float64
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %% [markdown]
# ### Step 4: Review the data for duplicated values, and drop them if necessary.

# %%
# Review the data for duplicate values, and drop them if necessary

bitstamp.duplicated().sum()
# Out:
# 0

# %%
# It's not necessary to drop duplicates because they have different timestamps,
# It just happened that prices didn't change or came back to same levels

# %% [markdown]
# ### Step 5: Repeat Steps 1–4 for the coinbase DataFrame.

# %%
# Repeat Steps 1–4 for the coinbase DataFrame

# Check how many missing values are there in the DataFrame
coinbase.isnull().sum()
# Out:
# Open              218
# High              218
# Low               218
# Close               0
# BTC Volume        218
# USD Volume        218
# Weighted Price    218
# dtype: int64

# %%
# Drop all NaNs or missing values in the DataFrame

coinbase = coinbase.dropna()

# %%
# Use the str.replace function to remove the dollar sign, $

coinbase.loc[:, "Close"] = coinbase.loc[:, "Close"].str.replace("$", "", regex=True)

# Alternative code: coinbase["Close"] = coinbase["Close"].str.replace("$", "", regex=True)

# Call the head function to review the first 5 rows of the DataFrame
coinbase.head()
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401

# %%
# Convert the Close data type to a float
coinbase.loc[:, "Close"] = coinbase.loc[:, "Close"].astype("float")

# Alternative code: coinbase["Close"] = coinbase["Close"].astype("float")

# Review data types after conversion
coinbase.dtypes
# Out:
# Open              float64
# High              float64
# Low               float64
# Close             float64
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %%
# Review the data for duplicate values, and drop them if necessary

coinbase.duplicated().sum()
# Out:
# 0

# %%
# It's not necessary to drop duplicates because they have different timestamps,
# It just happened that prices didn't change or came back to same levels

# %%
display(bitstamp.head())
display(coinbase.head())
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00  13620.00    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  13608.49   20.812754
# ...

# %% [markdown]
# ## Analyze the Data
#
# Your analysis consists of the following tasks:
#
# 1. Choose the columns of data on which to focus your analysis.
#
# 2. Get the summary statistics and plot the data.
#
# 3. Focus your analysis on specific dates.
#
# 4. Calculate the arbitrage profits.

# %% [markdown]
# ### Step 1: Choose columns of data on which to focus your analysis.
#
# Select the data you want to analyze. Use `loc` or `iloc` to select the following columns of data for both the bitstamp and coinbase DataFrames:
#
# * Timestamp (index)
#
# * Close

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from bitstamp DataFrame
bitstamp_sliced = bitstamp.loc[ : , 'Close']

# Review the first five rows of the DataFrame
bitstamp_sliced.head()
# Out:
# Timestamp
# 2018-01-01 00:00:00    13646.48
# 2018-01-01 00:01:00    13658.75
# 2018-01-01 00:02:00    13610.22
# 2018-01-01 00:03:00    13639.09
# 2018-01-01 00:04:00    13620.00
# Name: Close, dtype: float64

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from coinbase DataFrame
coinbase_sliced = coinbase.loc[ : , 'Close']

# Review the first five rows of the DataFrame
coinbase_sliced.head()
# Out:
# Timestamp
# 2018-01-01 00:00:00    13608.49
# 2018-01-01 00:01:00    13601.66
# 2018-01-01 00:02:00    13580.00
# 2018-01-01 00:03:00    13550.34
# 2018-01-01 00:04:00    13583.44
# Name: Close, dtype: float64

# %% [markdown]
# ### Step 2: Get summary statistics and plot the data.
#
# Sort through the time series data associated with the bitstamp and coinbase DataFrames to identify potential arbitrage opportunities. To do so, complete the following steps:
#
# 1. Generate the summary statistics for each DataFrame by using the `describe` function.
#
# 2. For each DataFrame, create a line plot for the full period of time in the dataset. Be sure to tailor the figure size, title, and color to each visualization.
#
# 3. In one plot, overlay the visualizations that you created in Step 2 for bitstamp and coinbase. Be sure to adjust the legend and title for this new visualization.
#
# 4. Using the `loc` and `plot` functions, plot the price action of the assets on each exchange for different dates and times. Your goal is to evaluate how the spread between the two exchanges changed across the time period that the datasets define. Did the degree of spread change as time progressed?

# %%
# Generate the summary statistics for the bitstamp DataFrame
bitstamp_sliced.describe()
# Out:
# count    129067.000000
# mean      10459.842453
# std        2315.976088
# min        5944.000000
# 25%        8613.370000
# 50%       10145.950000
# 75%       11444.810000
# max       17234.980000
# Name: Close, dtype: float64

# %%
# Generate the summary statistics for the coinbase DataFrame
coinbase_sliced.describe()
# Out:
# count    129322.000000
# mean      10449.140958
# std        2317.197419
# min        5882.310000
# 25%        8609.230000
# 50%       10137.440000
# 75%       11397.237500
# max       17177.990000
# Name: Close, dtype: float64

# %%
# Create a line plot for the bitstamp DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
bitstamp_sliced.plot(
    figsize=(15, 10), 
    title="BTC Price on Bitstamp", 
    color="blue")
# Out:
# <AxesSubplot:title={'center':'BTC Price on Bitstamp'}, xlabel='Timestamp'>

# %%
# Create a line plot for the coinbase DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
coinbase_sliced.plot(
    figsize=(15, 10), 
    title="BTC Price on Coinbase", 
    color="orange")
# Out:
# <AxesSubplot:title={'center':'BTC Price on Coinbase'}, xlabel='Timestamp'>

# %%
# Overlay the visualizations for the bitstamp and coinbase DataFrames in one plot
# The plot should visualize the prices over the full lenth of the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
bitstamp_sliced.plot(
    legend=True, 
    figsize=(15, 10), 
    title="BTC Price on Bitstamp vs Coinbase", 
    color="blue", 
    label="Bitstamp");
coinbase_sliced.plot(
    legend=True, 
    figsize=(15, 10), 
    color="orange", 
    label="Coinbase");

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period early in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
bitstamp_sliced.loc['2018-01-01':'2018-01-31'].plot(
    legend=True, 
    figsize=(15, 10), 
    title="BTC Price on Bitstamp vs Coinbase in Jan 2018", 
    color="blue", 
    label="Bitstamp");
coinbase_sliced.loc['2018-01-01':'2018-01-31'].plot(
    legend=True, 
    figsize=(15, 10), 
    color="orange", 
    label="Coinbase");

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period later in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label 
bitstamp_sliced.loc['2018-03-01':'2018-03-31'].plot(
    legend=True, 
    figsize=(15, 10), 
    title="BTC Price on Bitstamp vs Coinbase in Mar 2018", 
    color="blue", 
    label="Bitstamp");
coinbase_sliced.loc['2018-03-01':'2018-03-31'].plot(
    legend=True, 
    figsize=(15, 10), 
    color="orange", 
    label="Coinbase");

# %% [markdown]
# **Question** Based on the visualizations of the different time periods, has the degree of spread change as time progressed?
#
# **Answer** The degree of spread was higher in the early slice of the data set than in a later slice.

# %% [markdown]
# ### Step 3: Focus Your Analysis on Specific Dates
#
# Focus your analysis on specific dates by completing the following steps:
#
# 1. Select three dates to evaluate for arbitrage profitability. Choose one date that’s early in the dataset, one from the middle of the dataset, and one from the later part of the time period.
#
# 2. For each of the three dates, generate the summary statistics and then create a box plot. This big-picture view is meant to help you gain a better understanding of the data before you perform your arbitrage calculations. As you compare the data, what conclusions can you draw?

# %%
early_date = '2018-01-28'
middle_date = '2018-02-06'
late_date = '2018-03-13'

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day early in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
early_price_spread_plot = bitstamp_sliced.loc[early_date].plot(
    legend=True, 
    figsize=(15, 10), 
    title=f"BTC Price on Bitstamp vs Coinbase (Early): {early_date}", 
    color="blue", 
    label="Bitstamp");
coinbase_sliced.loc[early_date].plot(
    legend=True, 
    figsize=(15, 10), 
    color="orange", 
    label="Coinbase");

# Save the plot figure for documentation
early_price_spread_figure = early_price_spread_plot.get_figure()
early_price_spread_figure.savefig('images/early_price_spread.png')

# %%
# Using the early date that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_early = bitstamp_sliced.loc[early_date] - coinbase_sliced.loc[early_date]

# Generate summary statistics for the early DataFrame
arbitrage_spread_early.describe()
# Out:
# count    1436.000000
# mean      247.552326
# std        68.343472
# min        55.030000
# 25%       210.022500
# 50%       251.180000
# 75%       290.925000
# max       439.010000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from early in the dataset in a box plot
arbitrage_spread_early.plot(kind = 'box', title=f"Arbitrage Spread (Early): {early_date}");

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from the middle of the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
middle_price_spread_plot = bitstamp_sliced.loc[middle_date].plot(
    legend=True, 
    figsize=(15, 10), 
    title=f"BTC Price on Bitstamp vs Coinbase (Middle): {middle_date}", 
    color="blue", 
    label="Bitstamp");
coinbase_sliced.loc[middle_date].plot(
    legend=True, 
    figsize=(15, 10), 
    color="orange", 
    label="Coinbase");

# Save the plot figure for documentation
middle_price_spread_figure = middle_price_spread_plot.get_figure()
middle_price_spread_figure.savefig('images/middle_price_spread.png')

# %%
# Using the date in the middle that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_middle = bitstamp_sliced.loc[middle_date] - coinbase_sliced.loc[middle_date]

# Generate summary statistics 
arbitrage_spread_middle.describe()
# Out:
# count    1440.000000
# mean       23.841236
# std        30.390321
# min       -51.000000
# 25%         4.675000
# 50%        19.375000
# 75%        37.877500
# max       280.010000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from the middle of the dataset in a box plot
arbitrage_spread_middle.plot(kind = 'box', title=f"Arbitrage Spread (Middle): {middle_date}");

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from late in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
late_price_spread_plot = bitstamp_sliced.loc[late_date].plot(
    legend=True, 
    figsize=(15, 10), 
    title=f"BTC Price on Bitstamp vs Coinbase (Late): {late_date}", 
    color="blue", 
    label="Bitstamp");
coinbase_sliced.loc[late_date].plot(
    legend=True, 
    figsize=(15, 10), 
    color="orange", 
    label="Coinbase");

# Save the plot figure for documentation
late_price_spread_figure = late_price_spread_plot.get_figure()
late_price_spread_figure.savefig('images/late_price_spread.png')

# %%
# Using the date from the late that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_late = bitstamp_sliced.loc[late_date] - coinbase_sliced.loc[late_date]

# Generate summary statistics for the late DataFrame
arbitrage_spread_late.describe()
# Out:
# count    1423.000000
# mean        5.111145
# std        12.253619
# min       -47.270000
# 25%        -3.095000
# 50%         4.660000
# 75%        13.365000
# max        65.000000
# Name: Close, dtype: float64

# %%
# Visualize the arbitrage spread from late in the dataset in a box plot
arbitrage_spread_late.plot(kind = 'box', title=f"Arbitrage Spread (Late): {late_date}");

# %% [markdown]
# ### Step 4: Calculate the Arbitrage Profits
#
# Calculate the potential profits for each date that you selected in the previous section. Your goal is to determine whether arbitrage opportunities still exist in the Bitcoin market. Complete the following steps:
#
# 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.
#
# 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.
#
# 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?
#
# 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.
#
# 6. Generate the summary statistics, and plot the results for each of the three DataFrames.
#
# 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.
#
# 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?
#
# (NOTE: The starter code displays only one date. You'll want to do this analysis for two additional dates).

# %% [markdown]
# #### 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# *NOTE*: For illustration, only one of the three dates is shown in the starter code below.

# %%
# For the date early in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one
arbitrage_spread_early = bitstamp_sliced.loc[early_date] - coinbase_sliced.loc[early_date]
arbitrage_spread_middle = bitstamp_sliced.loc[middle_date] - coinbase_sliced.loc[middle_date]
arbitrage_spread_late = bitstamp_sliced.loc[late_date] - coinbase_sliced.loc[late_date]

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
print(f"Summary statistics for early arbitrage_spread (on: {early_date}), where the spread is greater than zero:")
print(arbitrage_spread_early[arbitrage_spread_early>0].describe())
print(f"\nSummary statistics for middle arbitrage_spread (on: {middle_date}), where the spread is greater than zero:")
print(arbitrage_spread_middle[arbitrage_spread_middle>0].describe())
print(f"\nSummary statistics for late arbitrage_spread (on: {late_date}), where the spread is greater than zero:")
print(arbitrage_spread_late[arbitrage_spread_late>0].describe())
# Out:
# Summary statistics for early arbitrage_spread (on: 2018-01-28), where the spread is greater than zero:
# count    1436.000000
# mean      247.552326
# std        68.343472
# min        55.030000
# 25%       210.022500
# 50%       251.180000
# 75%       290.925000
# max       439.010000
# Name: Close, dtype: float64
#
# Summary statistics for middle arbitrage_spread (on: 2018-02-06), where the spread is greater than zero:
# count    1177.000000
# mean       31.294452
# std        28.481383
# min         0.010000
# 25%        13.000000
# 50%        24.530000
# 75%        42.540000
# max       280.010000
# Name: Close, dtype: float64
#
# Summary statistics for late arbitrage_spread (on: 2018-03-13), where the spread is greater than zero:
# count    930.000000
# mean      11.922226
# std        8.680349
# min        0.010000
# 25%        4.992500
# 50%       10.785000
# 75%       17.285000
# max       65.000000
# Name: Close, dtype: float64

# %% [markdown]
# #### 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).
spread_return_early= arbitrage_spread_early[arbitrage_spread_early>0] / coinbase_sliced.loc[early_date]
spread_return_middle= arbitrage_spread_middle[arbitrage_spread_middle>0] / coinbase_sliced.loc[middle_date]
spread_return_late= arbitrage_spread_late[arbitrage_spread_late>0] / coinbase_sliced.loc[late_date]

# Review the spread return DataFrame
print(f"Summary statistics for early arbitrage return (on: {early_date}):")
display(spread_return_early.describe())
print(f"\nSummary statistics for middle arbitrage return (on: {middle_date}):")
display(spread_return_middle.describe())
print(f"\nSummary statistics for late arbitrage return (on: {late_date}):")
display(spread_return_late.describe())
# Out:
# Summary statistics for early arbitrage return (on: 2018-01-28):
# count    1436.000000
# mean        0.021648
# std         0.005961
# min         0.004885
# 25%         0.018369
# 50%         0.021897
# 75%         0.025292
# max         0.038510
# Name: Close, dtype: float64
# Summary statistics for middle arbitrage return (on: 2018-02-06):
# count    1177.000000
# mean        0.004590
# std         0.004220
# min         0.000001
# 25%         0.001851
# 50%         0.003384
# 75%         0.006041
# max         0.036984
# Name: Close, dtype: float64
# Summary statistics for late arbitrage return (on: 2018-03-13):
# count    930.000000
# mean       0.001300
# std        0.000944
# min        0.000001
# 25%        0.000545
# 50%        0.001179
# 75%        0.001886
# max        0.007077
# Name: Close, dtype: float64

# %% [markdown]
# #### 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.

# %%
# For the date early in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
profitable_trades_early = spread_return_early[spread_return_early>0.01]
profitable_trades_middle = spread_return_middle[spread_return_middle>0.01]
profitable_trades_late = spread_return_late[spread_return_late>0.01]

# Review the first five profitable trades
print(f"The first five early profitabel trades (on: {early_date}):")
display(profitable_trades_early.head())
print(f"\nThe first five middle profitabel trades (on: {middle_date}):")
display(profitable_trades_middle.head())
print(f"\nThe first five late profitabel trades (on: {late_date}):")
display(profitable_trades_late.head())
# Out:
# The first five early profitabel trades (on: 2018-01-28):
# Timestamp
# 2018-01-28 00:00:00    0.023999
# 2018-01-28 00:01:00    0.023965
# 2018-01-28 00:02:00    0.023392
# 2018-01-28 00:03:00    0.023936
# 2018-01-28 00:04:00    0.025610
# Name: Close, dtype: float64
# The first five middle profitabel trades (on: 2018-02-06):
# Timestamp
# 2018-02-06 00:00:00    0.010084
# 2018-02-06 00:02:00    0.012606
# 2018-02-06 00:03:00    0.014129
# 2018-02-06 00:04:00    0.016004
# 2018-02-06 00:05:00    0.019154
# Name: Close, dtype: float64
# The first five late profitabel trades (on: 2018-03-13):
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# #### 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?

# %%
# For the date early in the dataset, generate the summary statistics for the profitable trades
# or you trades where the spread returns are are greater than 1%
print(f"Summary statistics for early profitable trades (on: {early_date}):")
display(profitable_trades_early.describe())
print(f"\nSummary statistics for middle profitable trades (on: {middle_date}):")
display(profitable_trades_middle.describe())
print(f"\nSummary statistics for late profitable trades (on: {late_date}):")
display(profitable_trades_middle.describe())
# Out:
# Summary statistics for early profitable trades (on: 2018-01-28):
# count    1378.000000
# mean        0.022201
# std         0.005421
# min         0.010087
# 25%         0.019016
# 50%         0.022191
# 75%         0.025413
# max         0.038510
# Name: Close, dtype: float64
# Summary statistics for middle profitable trades (on: 2018-02-06):
# count    110.000000
# mean       0.014312
# std        0.005292
# min        0.010084
# 25%        0.010822
# 50%        0.012209
# 75%        0.015809
# max        0.036984
# Name: Close, dtype: float64
# Summary statistics for late profitable trades (on: 2018-03-13):
# count    110.000000
# mean       0.014312
# std        0.005292
# min        0.010084
# 25%        0.010822
# 50%        0.012209
# 75%        0.015809
# max        0.036984
# Name: Close, dtype: float64

# %% [markdown]
# #### 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased
profit_early = profitable_trades_early * coinbase_sliced.loc[early_date]
profit_middle = profitable_trades_middle * coinbase_sliced.loc[middle_date]
profit_late = profitable_trades_late * coinbase_sliced.loc[late_date]

# Drop any missing values from the profit DataFrame
profit_per_trade_early = profit_early.dropna()
profit_per_trade_middle = profit_middle.dropna()
profit_per_trade_late = profit_late.dropna()

# View the early profit DataFrame
print(f"The first five rows in early profit per trade (on: {early_date}):")
display(profit_per_trade_early.head())
print(f"\nThe first five rows in middle profit per trade (on: {middle_date}):")
display(profit_per_trade_middle.head())
print(f"\nThe first five rows in late profit per trade (on: {late_date}):")
display(profit_per_trade_late.head())
# Out:
# The first five rows in early profit per trade (on: 2018-01-28):
# Timestamp
# 2018-01-28 00:00:00    275.38
# 2018-01-28 00:01:00    275.00
# 2018-01-28 00:02:00    268.77
# 2018-01-28 00:03:00    275.03
# 2018-01-28 00:04:00    294.26
# Name: Close, dtype: float64
# The first five rows in middle profit per trade (on: 2018-02-06):
# Timestamp
# 2018-02-06 00:00:00     61.12
# 2018-02-06 00:02:00     75.95
# 2018-02-06 00:03:00     84.99
# 2018-02-06 00:04:00     96.09
# 2018-02-06 00:05:00    115.00
# Name: Close, dtype: float64
# The first five rows in late profit per trade (on: 2018-03-13):
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# #### 6. Generate the summary statistics, and plot the results for each of the three DataFrames.

# %%
# Generate the summary statistics for the early profit per trade DataFrame
print(f"Summary statistics for early profit per trade (on: {early_date}):")
display(profit_per_trade_early.describe())
print(f"\nSummary statistics for middle profit per trade (on: {middle_date}):")
display(profit_per_trade_middle.describe())
print(f"\nSummary statistics for late profit per trade (on: {late_date}):")
display(profit_per_trade_late.describe())
# Out:
# Summary statistics for early profit per trade (on: 2018-01-28):
# count    1378.000000
# mean      253.931996
# std        62.057953
# min       113.970000
# 25%       217.272500
# 50%       254.150000
# 75%       292.987500
# max       439.010000
# Name: Close, dtype: float64
# Summary statistics for middle profit per trade (on: 2018-02-06):
# count    110.000000
# mean      94.872545
# std       41.169942
# min       61.120000
# 25%       68.205000
# 50%       80.010000
# 75%      106.697500
# max      280.010000
# Name: Close, dtype: float64
# Summary statistics for late profit per trade (on: 2018-03-13):
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %%
# Plot the results for the early profit per trade DataFrame
profit_per_trade_early_plot = profit_per_trade_early.plot(
    figsize=(15, 10), 
    title=f"Early Profit Per Trade on: {early_date}");

# Save the plot figure for documentation
profit_per_trade_early_figure = profit_per_trade_early_plot.get_figure()
profit_per_trade_early_figure.savefig('images/early_profit_per_trade.png')

# %%
profit_per_trade_middle_plot = profit_per_trade_middle.plot(
    figsize=(15, 10), 
    title=f"Middle Profit Per Trade on: {middle_date}");

# Save the plot figure for documentation
profit_per_trade_middle_figure = profit_per_trade_middle_plot.get_figure()
profit_per_trade_middle_figure.savefig('images/middle_profit_per_trade.png')

# %%
profit_per_trade_late_plot = profit_per_trade_late.plot(
    figsize=(15, 10), 
    title=f"Late Profit Per Trade on: {late_date}");

# Save the plot figure for documentation
profit_per_trade_late_figure = profit_per_trade_late_plot.get_figure()
profit_per_trade_late_figure.savefig('images/late_profit_per_trade.png')

# %% [markdown]
# #### 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.

# %%
# Calculate the sum of the potential profits for the early profit per trade DataFrame
print(f"The sum of the potential profits for the early profit per trade on {early_date}:")
print(profit_per_trade_early.sum())
print(f"\nThe sum of the potential profits for the middle profit per trade on {middle_date}:")
print(profit_per_trade_middle.sum())
print(f"\nThe sum of the potential profits for the late profit per trade on {late_date}:")
print(profit_per_trade_late.sum())
# Out:
# The sum of the potential profits for the early profit per trade on 2018-01-28:
# 349918.2900000001
#
# The sum of the potential profits for the middle profit per trade on 2018-02-06:
# 10435.979999999996
#
# The sum of the potential profits for the late profit per trade on 2018-03-13:
# 0.0

# %% [markdown]
# #### 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?

# %%
# Use the cumsum function to calculate the cumulative profits over time for the early profit per trade DataFrame
cumulative_profit_early = profit_per_trade_early.cumsum()
cumulative_profit_middle = profit_per_trade_middle.cumsum()
cumulative_profit_late = profit_per_trade_late.cumsum()

# %%
# Plot the cumulative sum of profits for the early profit per trade DataFrame
cumulative_profit_early_plot = cumulative_profit_early.plot(
    figsize=(15, 10), 
    title=f"Cumulative Sum of Early Profits on: {early_date}");

# Save the plot figure for documentation
cumulative_profit_early_figure = cumulative_profit_early_plot.get_figure()
cumulative_profit_early_figure.savefig('images/early_cumulative_profit.png')

# %%
cumulative_profit_middle_plot = cumulative_profit_middle.plot(
    figsize=(15, 10), 
    title=f"Cumulative Sum of Middle Profits on: {middle_date}");

# Save the plot figure for documentation
cumulative_profit_middle_figure = cumulative_profit_middle_plot.get_figure()
cumulative_profit_middle_figure.savefig('images/middle_cumulative_profit.png')

# %%
cumulative_profit_late_plot = cumulative_profit_late.plot(
    figsize=(15, 10), 
    title=f"Cumulative Sum of Late Profits on: {late_date}");

# Save the plot figure for documentation
cumulative_profit_late_figure = cumulative_profit_late_plot.get_figure()
cumulative_profit_late_figure.savefig('images/late_cumulative_profit.png')

# %% [markdown]
# **Question:** After reviewing the profit information across each date from the different time periods, can you identify any patterns or trends?
#
# **Answer:** After analyzing multiple early, middle, and late date, the data shows that arbitrage trading was the highest in the early dates, then over time it was diminishing. This makes sense as more people wanted to capture available arbitrage, which results in creating a balanced priced in both exchanges.
